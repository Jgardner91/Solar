# %%
import os
import time
import datetime

# %%
def remove_cache():
    for i in range(100):
        location_1 = '/Users/jamesgardner/Library/Caches/Google/Chrome/Default/Cache/Cache_Data'
        cached = os.listdir('/Users/jamesgardner/Library/Caches/Google/Chrome/Default/Cache/Cache_Data')
        print(len(cached))
       
        for file in cached:
            if file != 'index-dir':
                path = os.path.join(location_1,file)
                os.remove(path)
        
        cached = os.listdir('/Users/jamesgardner/Library/Caches/Google/Chrome/Default/Cache/Cache_Data')
        print(len(cached))
        
        now = datetime.datetime.now()
        print(now.strftime("%d/%m/%Y %H:%M:%S"))
        time.sleep(300)

# %%
remove_cache()
# Out:
# 7
# 1
# 06/01/2022 16:56:59
# 12
# 1
# 06/01/2022 17:01:59
# 11
# 1
# 06/01/2022 17:06:59
# 12
# 1
# 06/01/2022 17:12:00
# 11
# 1
# 06/01/2022 17:17:00
# 12
# 1
# 06/01/2022 17:22:00
# 11
# 1
# 06/01/2022 17:27:00
# 12
# 1
# 06/01/2022 17:32:00
# 17
# 1
# 06/01/2022 17:37:00
# 12
# 1
# 06/01/2022 17:42:00
# 11
# 1
# 06/01/2022 17:47:00
# 12
# 1
# 06/01/2022 17:52:00
# 11
# 1
# 06/01/2022 17:57:00
# 12
# 1
# 06/01/2022 18:02:00
# 11
# 1
# 06/01/2022 18:07:00
# 12
# 1
# 06/01/2022 18:12:00
# 11
# 1
# 06/01/2022 18:17:00
# 12
# 1
# 06/01/2022 18:22:00
# 11
# 1
# 06/01/2022 18:27:00
# 12
# 1
# 06/01/2022 18:32:00
# 14
# 1
# 06/01/2022 18:37:00
# 12
# 1
# 06/01/2022 18:42:00
# 11
# 1
# 06/01/2022 18:47:00
# 12
# 1
# 06/01/2022 18:52:00
# 11
# 1
# 06/01/2022 18:57:00
# 12
# 1
# 06/01/2022 19:02:00
# 8
# 1
# 06/01/2022 19:07:00
# 1
# 1
# 06/01/2022 19:12:00
# 1
# 1
# 06/01/2022 19:17:00
# 1
# 1
# 06/01/2022 19:22:00
# 3
# 1
# 06/01/2022 19:27:00
# 4
# 1
# 06/01/2022 19:32:00
# 9
# 1
# ...

# %%
import pandas as pd
pd.read_pickle("SolarDataZip11000_15000")
# Out:
#      State          City ZipCode RecievedQuote  NumQuotes
# 0       NC    BURLINGTON   27215            40        120
# 1       NC    BURLINGTON   27216            40        120
# 2       NC    BURLINGTON   27217            75        225
# 3       NC         BYNUM   27228           160        480
# 4       NC        CANDOR   27229            40        120
# ...    ...           ...     ...           ...        ...
# 3790    FL  PORT SALERNO   34992           275        825
# 3791    FL        STUART   34994            90        270
# 3792    FL        STUART   34995            80        240
# 3793    FL        STUART   34996            60        180
# 3794    FL        STUART   34997            70        210
#
# [3795 rows x 5 columns]
